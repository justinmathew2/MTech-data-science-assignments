# %% [markdown]
# <center><img src = "https://www.bits-pilani.ac.in/wp-content/uploads/BITS_university_logo.gif">

# %% [markdown]
# <h1><center>Work Integrated Learning Programmes Division<br>
# M.Tech (Data Science and Engineering)<br> Data Visualization And Interpretation )<br>
# Second Semester, 2022-23
# </center></h1>
#
# <h2><center>Assignment 2</center></h2>

# %% [markdown]
# <ol>
#   <li>Do not change the name of the data file that is shared with the problem statement.</li>
#   <li>If intermediate data files are created, retain in the present working directory and attach them during submission.</li>
#   <li>Retain the data file in the same directory as that of this workbook.</li>
#   <li>Retain the Visualizations that is produced in the file. Don't clear them away.</li>
#      <li><div class="alert-warning">All the visuals should adhere to the visualization principles learnt in the Course and must be presentation ready.Most effective visuals would fetch maximum credits</div></li>
#     <li><div class="alert-warning">Submissions done via means other than CANVAS will strictly be NOT graded.</div></li>
# </ol>

# %% [markdown]
# <h3>Objective</h3>
# <h4>What are the features that have the most impact on the car price?</h4>

# %% [markdown]
# ##  Download and Prep the Data:

# %% [markdown]
# <h4>Import the libraries needed</h4>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h4> Load data and store in dataframe </h4>

# %%
df=pd.read_csv('dvi-a2-ps3-data.csv')
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# <h4>Find out  what type of variable you are dealing with. This will help you find the right visualization method for that variable.</p>

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %% [markdown]
# <h4> Find the correlation between the following columns: bore, stroke, compression-ratio, and horsepower.<br>
# Write down your observations in a markdown cell below. <h4>

# %%
columns = ['bore', 'stroke', 'compression-ratio', 'horsepower']
correlation_matrix = df[columns].corr()
print(correlation_matrix)
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %% [markdown]
# **Observations:**
#
# *   'bore' and 'horsepower' have a moderate positive correlation.
# *   'stroke' and 'compression-ratio' have a weak positive correlation.
# *   The other pairs of variables ('bore' and 'stroke', 'bore' and 'compression-ratio', 'stroke' and 'horsepower', 'compression-ratio' and 'horsepower') have very weak or negligible correlations. The correlations are moderate or weak, suggesting that other factors may have more influence on these variables in the dataset.

# %% [markdown]
# # Visualisation Questions

# %% [markdown]
# ### Question 1
# <h4>What kind of a correlation exists between<br><br>
#     a."engine-size" and "price"<br><br>
#     b."highway-mpg" and "price"<br><br>
#     c."peak-rpm" and "price"<br><br>
#     Use appropriate visuals to demonstrate the same.Use subplots.
# <h4>Clearly mention in markdown cells below the visual <br><br>1.You observataion about the relationship. Which among engine-size, highway-mpg and peak-rpm is a potential predictor variable of price.<br>
#     2.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     3.Mention the gestalt principles used.(atleast 2)<br>

# %%
# Subplot with 1 row and 3 columns
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Scatter plot and correlation for engine-size vs price
sns.scatterplot(x='engine-size', y='price', data=df, ax=axes[0])
corr_engine_size_price = df['engine-size'].corr(df['price'])
axes[0].set_title(f'Correlation: {corr_engine_size_price:.2f}', fontsize=12, color='green')

# Scatter plot and correlation for highway-mpg vs price
sns.scatterplot(x='highway-mpg', y='price', data=df, ax=axes[1])
corr_highway_mpg_price = df['highway-mpg'].corr(df['price'])
axes[1].set_title(f'Correlation: {corr_highway_mpg_price:.2f}', fontsize=12, color='red')

# Scatter plot and correlation for peak-rpm vs price
sns.scatterplot(x='peak-rpm', y='price', data=df, ax=axes[2])
corr_peak_rpm_price = df['peak-rpm'].corr(df['price'])
axes[2].set_title(f'Correlation: {corr_peak_rpm_price:.2f}', fontsize=12, color='red')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation about the relationship**
#
# *   There is a positive correlation between engine size and price. As engine size increases, the price tends to increase. This relationship appears to be moderately strong.
# engine-size is a potential predictor variable of price.
#
# *   The other two (highway-mpg and peak-rpm) seems to have negative correlation between them, which suggests that they may not be a potential predictor variable of price. In case of highway-mpg we can see that as highway mpg increases, the price tends to decrease.
#
#
# **Pre-Attentive Attributes**
#
#
# *   Position: The position of data points on the plot conveys the relationship between variables. The x-axis represents one variable, the y-axis represents another variable, and the position of each point indicates their values.
#
# *   Color: The title of each subplot is color-coded to indicate the correlation coefficient. Positive correlations are displayed in one color, and negative correlations in another. This color coding helps draw attention to the strength and direction of the correlation.
#
# **Gestalt Principles**
#
#
# *   Proximity: The scatter plots are arranged in close proximity to each other in a single row, making it easy to compare the relationships between different pairs of variables.
#
# *   Similarity: The scatter plots share a similar structure, with axes, data points, and titles. This similarity helps viewers quickly understand the purpose and content of each plot.

# %% [markdown]
# ### Question 2
# <h4> Use boxplots to visualise the relationship between<br><br>
#     a."body-style" and "price". <br><br>
#     b."engine-location" and "price" <br><br>
#     c."drive-wheels"and "price" <br><br>
#     Use appropriate visuals to demonstrate the same.Use subplots.
# <h4>Clearly mention in markdown cells below the visual <br><br>1.Your observataion about the relationship .Which among engine-location ,body-style and drive-wheels is a potential predictor variable of price<br>
#     2.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     3.Mention the gestalt principles used.(atleast 2)<br>

# %%
# Subplot with 1 row and 3 columns
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Boxplot for body-style vs price
sns.boxplot(x='body-style', y='price', data=df, ax=axes[0])
axes[0].set_title('Body Style vs Price')

# Boxplot for engine-location vs price
sns.boxplot(x='engine-location', y='price', data=df, ax=axes[1])
axes[1].set_title('Engine Location vs Price')

# Boxplot for drive-wheels vs price
sns.boxplot(x='drive-wheels', y='price', data=df, ax=axes[2])
axes[2].set_title('Drive Wheels vs Price')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation about the relationship**
#
# *   There is a relationship between the body style of the cars and their prices. Convertibles and hardtops generally have higher price ranges compared to sedans and hatchbacks. This suggests that body-style could be a potential predictor variable of price.
#
# *   There is a significant relationship between the engine location and car prices. Cars with rear-engine placement tend to have higher prices compared to front-engine cars. This relationship is strong, and engine-location appears to be a potential predictor variable of price.
#
# *   The type of drive wheels also seems to be related to car prices, rwd cars seems to have higher prices than fwd and 4wd. This suggests that drive-wheels could be a potential predictor variable of price.
#
#
#
# **Pre-Attentive Attributes**
#
#
# *   Position: The position of the boxes and whiskers on the y-axis of the boxplots is used to convey the distribution of prices within different categories of the categorical variables.
#
# *   Length: The length of the boxes and whiskers represents the spread and variability of prices within each category, providing information about the distribution's range and quartiles.
#
# **Gestalt Principles**
#
#
# *  Proximity: The boxplots for each categorical variable are arranged in close proximity to each other in a single row, making it easy to compare the relationships between different categories and prices.
#
# *  Similarity: The boxplots share a similar structure with boxes and whiskers, which helps viewers quickly understand the distribution of prices within each category. This similarity aids in making comparisons between categories.

# %% [markdown]
# ### Question 3
# <h4> Perform a Descriptive Statistical Analysis of the data set.<br>
#     Compute basic statistics for all continuous variables.
#     <h4>Answer in markdown cells below the visual <br><br>
#         1.Summarise your findings from the visual.<br>
#             2.The reason for selecting the chart type you did. <br>
#                 3.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
# Selecting continuous variables
cont_vars = df.select_dtypes(include=['int64', 'float64'])

# Computing Basic statistics
basic_stats = cont_vars.describe().transpose()

# Print the basic statistics
print(basic_stats)
# Out:
#                    count          mean          std          min          25%  \
# symboling          201.0      0.840796     1.254802    -2.000000     0.000000
# normalized-losses  201.0    122.000000    31.996250    65.000000   101.000000
# wheel-base         201.0     98.797015     6.066366    86.600000    94.500000
# length             201.0      0.837102     0.059213     0.678039     0.801538
# width              201.0      0.915126     0.029187     0.837500     0.890278
# height             201.0     53.766667     2.447822    47.800000    52.000000
# curb-weight        201.0   2555.666667   517.296727  1488.000000  2169.000000
# engine-size        201.0    126.875622    41.546834    61.000000    98.000000
# bore               201.0      3.330692     0.268072     2.540000     3.150000
# stroke             197.0      3.256904     0.319256     2.070000     3.110000
# compression-ratio  201.0     10.164279     4.004965     7.000000     8.600000
# ...

# %%
# Set the figure size
plt.figure(figsize=(15, 10))

# Boxplot for each continuous variable
sns.boxplot(data=cont_vars, orient='h', palette='Set2')
plt.title('Boxplots of Continuous Variables')
plt.xlabel('Value')
plt.ylabel('Variable')

# Show the plot
plt.show()

# %% [markdown]
# **Findings from the visual**
#
# *   The price variable, which represents the price of cars, has a wide range, with values ranging from 5,118 to 45,400. This suggests significant variability in car prices in the dataset. Also we can see price variable has some outliers.
#
# * Curb-weight varies from 1,488 to 4,066, indicating differences in the weight of the cars. And peak-rpm varies from 4,150 to 5,500.
#
#
#
# **Reason for selecting the Boxplot**
#
# *   Boxplots are suitable for visualizing the spread and distribution of continuous variables. They provide key statistics like median, mean, quartiles and help identify outliers. They are effective for visualizing the spread and central tendency of continuous variables, making it easy to compare multiple variables at once.
#
# **Pre-attentive attributes**
#
# *   Position: The position of the boxes and whiskers provides information about the median, quartiles, and potential outliers.
#
# *   Length: The length of the box and whiskers in the box plots represents the spread and variability of the data within each variable, making it easy to compare the distributions.
#
#
# **Gestalt principles**
# *   Similarity: Similar formatting and coloring are used for all boxplots, making it easy to identify and compare variables.
#
# *   Proximity: Boxplots are arranged in close proximity to each other, allowing viewers to compare the distribution of different variables effectively.

# %% [markdown]
#   ### Question 4
#   <h4> Perform a Descriptive Statistical Analysis of the data set.<br>
#     Compute basic statistics for all variables of type 'Object'.
#     <h4>Answer in markdown cells below the visual <br><br>
#         1.Summarise your findings from the visual.<br>
#             2.The reason for selecting the chart type you did. <br>
#                 3.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
# Selecting variables of type Object
obj_vars = df.select_dtypes(include=['object'])

# Compute basic statistics
desc_stats = obj_vars.describe().transpose()

# Print the basic statistics
print(desc_stats)
# Out:
#                   count unique     top freq
# make                201     22  toyota   32
# aspiration          201      2     std  165
# num-of-doors        201      2    four  115
# body-style          201      5   sedan   94
# drive-wheels        201      3     fwd  118
# engine-location     201      2   front  198
# engine-type         201      6     ohc  145
# num-of-cylinders    201      7    four  157
# fuel-system         201      8    mpfi   92
# horsepower-binned   200      3     Low  115

# %%
# Set the number of rows and columns for subplots
num_rows = (len(obj_vars.columns) + 2) // 3
num_cols = 3

# Subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 20))
plt.subplots_adjust(wspace=0.4, hspace=0.4)

# Flatten the axes array
axes = axes.flatten()

# Bar plots for each categorical variable
for i, col in enumerate(obj_vars.columns):
    sns.countplot(data=df, y=col, palette='Set1', ax=axes[i])
    axes[i].set_xlabel('Count')
    axes[i].set_ylabel(col)
    axes[i].set_title(f'Distribution of {col}')

for j in range(len(obj_vars.columns), len(axes)):
    fig.delaxes(axes[j])

# Show the subplots
plt.show()

# %% [markdown]
# **Findings from the visual**
#
# *   There are 201 unique cars in the dataset from 22 different car manufacturers.
#
# * There are five unique values in the body-style variable, which describes the body style of the car (e.g., sedan, hatchback, convertible).
#
# *  There are three unique values in the horsepower-binned variable, which categorizes cars based on their horsepower.
#
# *   There are two unique values in the "engine-location" variable, which specifies whether the engine is located in the front or rear of the car.
#
#
#
#
#
# **Reason for selecting the Barplot**
#
# *  Horizontal Bar plots are chosen because they effectively display the distribution of categorical data and help visualize the frequency of each category. When visualizing multiple categorical variables, bar plots provide a clear and concise way to compare the distributions across variables.
#
# **Pre-attentive attributes**
#
# *   Length: The length of each bar in the bar plots represents the count of data points in a specific category, making it easy to compare counts.
#
# *   Color: Different colors are used for different categories, allowing viewers to distinguish between categories.
#
#
# **Gestalt principles**
# *   Proximity: Bar plots for each categorical variable are positioned next to each other, allowing viewers to compare distributions side by side.
#
# *   Continuity: The horizontal bars provide a continuous visual representation of the counts of car makes. Human eyes tries to find out the things aligned with each other in some order. So here elements are aligned linearly in decreasing order to facilitate comparison of different items without much difficulty.

# %% [markdown]
# ### Question 5
# <h4> Use a single heat map to visualize the relationship between Body Style and Drive-wheel vs Price.</h4>
# <h4>Perform the data preprocessing required.<br>
#
# <p>The heatmap should plot  the target variable (price) proportional to colour with respect to the variables 'drive-wheel' and 'body-style' in the vertical and horizontal axis respectively. This allows us to visualize how the price is related to 'drive-wheel' and 'body-style'.</p>
#
# The plot should have labels for x axis and y axis<br>
# Write down your observations in a markdown cell below the visual</h4>
#
# 1.Mention the pre-attentive attributes used.(atleast 2)<br>
# 2.Mention the gestalt principles used.(atleast 2)<br>

# %%
# Pivoting the data to create a heatmap
heatmap_data = df.pivot_table(index='drive-wheels', columns='body-style', values='price', aggfunc='mean')

# Set the figure size
plt.figure(figsize=(12, 8))

# Creating a heatmap
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="YlGnBu")

# Add labels to the axes
plt.xlabel('Body Style')
plt.ylabel('Drive Wheel')

# Set the title
plt.title('Heatmap: Price vs Body Style & Drive Wheel')

# Show the plot
plt.show()

# %% [markdown]
# **Observations**
#
# *   From the heatmap, we can observe how the average price varies for different combinations of Body Style and Drive Wheel.
#
# * It appears that convertible and hardtop body styles with rwd drive wheels tend to have higher average prices compared to other combinations.
#
# *  Sedan body styles with fwd and rwd drive wheels have a wider range of prices.
#
# **Pre-attentive attributes**
#
# *   Color: Color is used to represent the average price, with lighter colors indicating higher prices and darker colors indicating lower prices. This allows viewers to quickly identify price patterns.
#
# *   Orientation: The orientation of the heatmap, with Body Style on the vertical axis and Drive Wheel on the horizontal axis, allows viewers to understand the relationship between these categorical variables in the context of the price (continuous variable).
#
# **Gestalt principles**
# *   Similarity: Similar color shades are used for cells with similar price values, making it easier to group and compare them.
#
# *   Continuity: The heatmap uses continuous gradients of color to represent the price values. This continuity in color transitions helps viewers understand the gradual changes in price across different combinations of Body Style and Drive Wheel. It enables viewers to perceive trends and variations in a smooth and continuous manner.

# %% [markdown]
# # Group's choice
#
# #### Frame 1 (more) question which will help in the EDA(Exploratory Data Analysis) of the given data set and answer the same using the best visual.
#
#  1. Write the question in a markdown cell
#  2. Below the question,in a coding cell,write the python code to create the visual to answer the question
#
# <h4> Answer in markdown cells below the visual <br><br>
#    1.Summarise your findings from the visual.<br>
#    2.The reason for selecting the chart type you did. <br>
#    3.Mention the pre-attentive attributes used.(atleast 2)<br>
#    4.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# **Question which will help in the EDA(Exploratory Data Analysis) of the given data set:**
#
# What is the distribution of car makes in the dataset, and how many cars does each make represent?

# %%
# Number of cars for each make
make_counts = df['make'].value_counts()

# Set the figure size
plt.figure(figsize=(10, 6))

# Horizontal bar plot to visualize the distribution of car makes
sns.barplot(x=make_counts.values, y=make_counts.index, palette='Set1')

# Add labels to the axes
plt.xlabel('Number of Cars')
plt.ylabel('Car Make')

# Set the title
plt.title('Distribution of Car Makes')

# Show the plot
plt.show()

# %% [markdown]
# **Summary**
#
# The bar plot displays the distribution of car makes in the dataset. It provides insights into how many cars each make represents. Some makes are more common, while others are less common. From the plot its clear that Toyota is the most common car make in the dataset, with 32 cars.
#
# **Reason for selecting Horizontal Bar Plot**
#
# A horizonatal bar plot is chosen because it is effective for displaying the frequency or count of car makes in a dataset. It allows for easy comparison between different categories and provides a clear view of how many cars each make represents.
#
# **Pre Attentive Attributes**
#
# *   Length: The length of each bar represents the number of cars for a particular make, making it easy to compare the counts across different makes.
#
# *   Color: Different colors are used to distinguish between car makes, aiding in the identification of categories.
#
# **Gestalt Principles**
#
#
# *   Proximity: Car makes that have the same count are displayed closely together horizontally. This principle of proximity groups the bars that represent the same number of cars, making it easy for viewers to identify patterns in car make distribution based on the count.
#
# *   Continuity: The horizontal bars provide a continuous visual representation of the counts of car makes. Human eyes tries to find out the things aligned with each other in some order. So here elements are aligned linearly in decreasing order to facilitate comparison of different items without much difficulty.

# %% [markdown]
# <h3><center>END OF ASSIGNMENT</center><h34>
